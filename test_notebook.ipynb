# %%
import math
import torch
from torch import nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['figure.figsize'] = (13, 4)

import metrics as ms

torch.manual_seed(0)
np.random.seed(0)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
df = pd.read_csv("sample_data.csv")
source = np.array(df.iloc[:,0].values)
target = np.array(df.iloc[:,1].values)
prediction = np.array([ x*(1.1+0.3*np.random.rand()) for x in target])

# %%
plt.plot(source[:100], label="source")
plt.plot(target[:100], label="target")
plt.plot(prediction[:100], label="prediction")
plt.legend()
plt.show()

# %%
stats = ms.get_statistics(prediction)
# Out:
# mean: 0.40, std: 0.24, min: 0.00, max: 0.87

# %%
ms.get_sae(target, prediction, 6)
# Out:
# r:52.04026907421543,r_hat:67.44399774489457
# 0.2959963302401771

# %%
ms.get_TP(target, prediction, 0.3)
# Out:
# 50268.0

# %%
ms.get_F1(target, prediction, 0.3)
# Out:
# tp=50268.0
# fn=0.0
# Recall: 1.000
# tp=50268.0
# fp=10107.0
# Precision: 0.833
# 0.9086521515143299
